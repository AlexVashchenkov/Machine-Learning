# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import os
import requests

# %%
output_dir = "cats_and_dogs"

def parse_folder(driver, category_name, category_length):
    loaded_images = 0
    
    breed_dir = os.path.join(output_dir, category_name)
    os.makedirs(breed_dir, exist_ok=True)

    scroll_div = driver.find_element(By.XPATH, "/html/body/main/div[1]/div/div[5]/div[2]/div/div[2]/div/div[5]/div[2]/div/div/div[1]/div/div[3]")
    
    for pages in range(1, category_length // 30 + 1):
        
        for i in range(1, 31):
            image = driver.find_element(By.XPATH, f"/html/body/main/div[1]/div/div[5]/div[2]/div/div[2]/div/div[5]/div[2]/div/div/div[1]/div/div[3]/div[1]/div[{loaded_images + i}]/img")
            driver.execute_script("arguments[0].scrollIntoView(true);", image)
            img_data = requests.get(image.get_attribute("src")).content
            file_path = os.path.join(breed_dir, f"{loaded_images + i}.jpg")
            with open(file_path, "wb") as f:
                f.write(img_data)
            print(f"Сохранено: {file_path}")
            
        loaded_images += 30
        load_more = driver.find_element(By.CLASS_NAME, "sc-drHDoh.fQpLKW")
        driver.execute_script("arguments[0].click();", load_more)
        driver.execute_script("arguments[0].scrollTo(0, arguments[0].scrollHeight);", scroll_div)

# %%
import time

driver = webdriver.Chrome()

link = "https://www.kaggle.com/datasets/mmoreaux/audio-cats-and-dogs?select=cats_dogs"

driver.get(link)
time.sleep(2)
view_more = driver.find_element(By.XPATH, "/html/body/main/div[1]/div/div[5]/div[2]/div/div[2]/div/div[5]/div[1]/div[1]/div[2]/button")
maximize = driver.find_element(By.XPATH, "/html/body/main/div[1]/div/div[5]/div[2]/div/div[2]/div/div[5]/div[2]/div/div/div[1]/div/div[1]/div[2]")
driver.execute_script("arguments[0].scrollIntoView(true)", view_more)
maximize.click()

# %%
test = driver.find_element(By.XPATH, "/html/body/main/div[1]/div/div[5]/div[2]/div/div[2]/div/div[5]/div[2]/div/div/div/div[2]/div[1]/div/ul/li[1]/ul/li[1]/div")
train = driver.find_element(By.XPATH, "/html/body/main/div[1]/div/div[5]/div[2]/div/div[2]/div/div[5]/div[2]/div/div/div/div[2]/div[1]/div/ul/li[1]/ul/li[2]/div")

train.click()
test.click()

# %%
cats_test = driver.find_element(By.XPATH, "/html/body/main/div[1]/div/div[5]/div[2]/div/div[2]/div/div[5]/div[2]/div/div/div/div[2]/div[1]/div/ul/li[1]/ul/li[1]/ul/li[1]/div")
dogs_test = driver.find_element(By.XPATH, "/html/body/main/div[1]/div/div[5]/div[2]/div/div[2]/div/div[5]/div[2]/div/div/div/div[2]/div[1]/div/ul/li[1]/ul/li[1]/ul/li[2]/div")
cat_train = driver.find_element(By.XPATH, "/html/body/main/div[1]/div/div[5]/div[2]/div/div[2]/div/div[5]/div[2]/div/div/div/div[2]/div[1]/div/ul/li[1]/ul/li[2]/ul/li[1]/div")
dog_train = driver.find_element(By.XPATH, "/html/body/main/div[1]/div/div[5]/div[2]/div/div[2]/div/div[5]/div[2]/div/div/div/div[2]/div[1]/div/ul/li[1]/ul/li[2]/ul/li[2]/div")

dog_train.click()

# %%
number_of_items_div = driver.find_element(By.CLASS_NAME, "sc-ovuCP.sc-kwXLfY.jgWmzR.gTyLYZ").text
number_of_items = int(number_of_items_div.split(' ')[0][1:])

loaded = 30
category = "dogs"

for i in range(1, number_of_items+1):
    audio = driver.find_element(By.XPATH, f"/html/body/main/div[1]/div/div[5]/div[2]/div/div[2]/div/div[5]/div[2]/div/div/div/div[2]/div[1]/div/ul/li[1]/ul/li[2]/ul/li[2]/ul/li[{i}]/div")
    #driver.execute_script("window.scrollBy(0, 10)")
    audio.click()
    time.sleep(1)
    audio_src = driver.find_element(By.XPATH, "/html/body/main/div[1]/div/div[5]/div[2]/div/div[2]/div/div[5]/div[2]/div/div/div/div[1]/div/div[3]/audio")
    audio_data = requests.get(audio_src.get_attribute("src")).content
    file_path = os.path.join("cats_dogs", category + f"_{loaded + i}.wav")
    with open(file_path, "wb") as f:
        print(f"Сохранено: {file_path}")
    continue
# Out:
# Сохранено: cats_dogs\dogs_31.wav
# Сохранено: cats_dogs\dogs_32.wav
# Сохранено: cats_dogs\dogs_33.wav
# Сохранено: cats_dogs\dogs_34.wav
# Сохранено: cats_dogs\dogs_35.wav
# Сохранено: cats_dogs\dogs_36.wav
# Сохранено: cats_dogs\dogs_37.wav
# Сохранено: cats_dogs\dogs_38.wav
# Сохранено: cats_dogs\dogs_39.wav
# Сохранено: cats_dogs\dogs_40.wav
# Сохранено: cats_dogs\dogs_41.wav
# Сохранено: cats_dogs\dogs_42.wav
# Сохранено: cats_dogs\dogs_43.wav
# Сохранено: cats_dogs\dogs_44.wav
# Сохранено: cats_dogs\dogs_45.wav
# Сохранено: cats_dogs\dogs_46.wav
# Сохранено: cats_dogs\dogs_47.wav
# Сохранено: cats_dogs\dogs_48.wav
# Сохранено: cats_dogs\dogs_49.wav
# Сохранено: cats_dogs\dogs_50.wav
# Сохранено: cats_dogs\dogs_51.wav
# Сохранено: cats_dogs\dogs_52.wav
# Сохранено: cats_dogs\dogs_53.wav
# Сохранено: cats_dogs\dogs_54.wav
# Сохранено: cats_dogs\dogs_55.wav
# Сохранено: cats_dogs\dogs_56.wav
# Сохранено: cats_dogs\dogs_57.wav
# Сохранено: cats_dogs\dogs_58.wav
# ...
